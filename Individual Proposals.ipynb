# %%
import pandas as pd
pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/refs/heads/main/CP/CSCS_data_anon.csv")
# Out:
# /tmp/ipykernel_70/2323921300.py:2: DtypeWarning: Columns (408,1001,1002,1006,1007,1008,1080,1113,1115,1116,1117,1118,1119,1120,1121,1124,1125,1126,1127,1128,1213,1214,1215,1216,1217,1218,1342,1343,1344,1345,1346,1347,1348,1349,1390,1391,1393,1463,1549,1552,1555,1558,1561) have mixed types. Specify dtype option on import or set low_memory=False.
#   pd.read_csv("https://raw.githubusercontent.com/pointOfive/stat130chat130/refs/heads/main/CP/CSCS_data_anon.csv")
#         UNIQUE_id  UNIQUE_num_records ELIGIBLE_consent GEO_residence_canada  \
# 0      cscs_00001                   1              Yes                  Yes
# 1      cscs_00002                   1              Yes                  Yes
# 2      cscs_00003                   1              Yes                  Yes
# 3      cscs_00005                   1              Yes                  Yes
# 4      cscs_00006                   1              Yes                  Yes
# ...

# %% [markdown]
# # Analysis 1: Demographic Factors and Types of Social Connection preference
#
# research question: does types of social connections differ across age, gender, and socioeconomic groups, if so how?
#
#
# 1. Describe (a) the variables you plan to explore, and (b) the analysis you plan to perform
#
# (a)
# Demographic Variables: Age, and socioeconomic status.
#
# Social Connection Variables: Types of social relationships (CONNECTION_preference Q29_1-4)
# (e.g., family, friends, coworkers).
#
# (b) the analysis
#
# Use dendrograms and cluster plots to display clusters.
# Perform a cluster analysis to group individuals based on similarities in social connection types and demographic characteristics. In this way, we can identify how social connection types vary across different demographic groups
# and see does demographic play role in social connection for example, does teenager like to spend more time socializing with friends compare to adults.
#
# 2. Describe (a) the possible results your analysis may produce, and (b) how this could be relevant for the objectives of the course project
#
# (a)The analysis may show distinct trends in how different demographic groups engage and their preference with social connections. For example, younger individuals might be found to prioritize friendships and peer interactions more, while older adults focus on family, showing a stronger connection to family or community-based relationships.
#
# Gender may also impact the social connection, for example women might have higher engagement with close family or community activities compared to men. Additionally, socioeconomic status could reveal variations, with those in higher income potentially reporting more diverse types of social interactions.
#
#
# (b)the aim of this analysis is to draw meaningful conclusions about social behavior trends in various demographic segments, offering insights that can be used for targeted community engagement strategies. The analysis can draw a trend and preference of how different demograhic relate to social connection ultimately linked to importance of social connection and community engagement which is the focus on this project.

# %% [markdown]
# # Analysis 2: Predictive Modeling for Well-Being Outcomes
#
# research question: does social connections impact overall well-being?
#
# 1. Describe (a) the variables you plan to explore, and (b) the analysis you plan to perform
#
# (a)
# Independent Variables: CONNECTION_meaningful_interactions, CONNECTION_social_num_close_friends_grouped
#
# Dependent Variable: WELLNESS_life_satisfaction (Q16) (scale 1-10)
#
# (b) the analysis
# Use simple linear regression to analyze the relationship between each social factor and well-being. Include visualization with scatter plots and regression lines. where independent variables such as the frequency of social activities, quality of interactions, and level of community involvement are tested against a composite well-being index (the dependent variable).
#
#
# 2. Describe (a) the possible results your analysis may produce, and (b) how this could be relevant for the objectives of the course project
#
# (a)The predictive model could reveal that certain aspects of social connections are strong predictors of well-being and life satisfaction. For instance, the analysis might find that the quality of interactions (e.g., meaningful conversations) has a higher impact on well-being than the sheer number of interactions.
#
# (b)These results would help pinpoint the most influential aspects of social connections, guiding interventions aimed at improving public health by focusing on enhancing the quality and depth of social relationships which might
# help raise awareness about the importanece of relationships with family, friends, coworkers, neighbours, and strangers for personal health and well-being which is the objectie of this porject.

# %% [markdown]
# # Analysis 3: Social Isolation and Personal Satisfaction
#
# research question: How does social isolation affect self-satisfaction?
#
# 1. Describe (a) the variables you plan to explore, and (b) the analysis you plan to perform
#
# (a)
# Independent Variable: Levels of social isolation (LONELY_ucla_loneliness_scale_isolated)
#
# Dependent Variable: Self-satisfaction (WELLNESS_life_satisfaction)
#
# (b) the analysis
# Conduct a regression analysis to examine the relationship between social isolation and self-satisfaction, controlling for variables like age, employment status, and income level.
#
# 2. Describe (a) the possible results your analysis may produce, and (b) how this could be relevant for the objectives of the course project
#
# (a) The results might indicate a significant inverse relationship between social isolation and self-satisfaction, demonstrated by a negative slope in the regression line. For example, individuals reporting higher levels of isolation could have notably lower self-satisfaction scores, highlighting the detrimental effects of social disconnection on personal well-being.
#
# (b)These findings would underscore the importance of fostering social connections to combat isolation and improve life satisfaction, supporting the course project’s objective to raise awareness of how social engagement affects personal well-being.
